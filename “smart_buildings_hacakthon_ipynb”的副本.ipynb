# %%
#@title Dataset Definition

"""Smart Buildings Dataset implementation, including loading and downloading."""


import json
import pickle
import shutil
import numpy as np
import requests





class SmartBuildingsDataset:
 """Smart Buildings Dataset implementation, including loading and downloading."""


 def __init__(self, download=True):
   self.partitions = {
       "sb1": [
           "2022_a",
           "2022_b",
           "2023_a",
           "2023_b",
           "2024_a",
       ],
   }
   if download:
     self.download()


 def download(self):
   """Downloads the Smart Buildings Dataset from Google Cloud Storage."""
   print("Downloading data...")


   def download_file(url):
     local_filename = url.split("/")[-1]
     with requests.get(url, stream=True) as r:
       r.raise_for_status()
       with open(local_filename, "wb") as f:
         for chunk in r.iter_content(chunk_size=8192):
           f.write(chunk)
     return local_filename


   url = "https://storage.googleapis.com/gresearch/smart_buildings_dataset/tabular_data/sb1.zip"
   download_file(url)
   shutil.unpack_archive("sb1.zip", "sb1/")


 def get_floorplan(self, building):
   """Gets the floorplan and device layout map for a specific building.


   Args:
     building: The name of the building.


   Returns:
     A tuple containing the floorplan and device layout map.
   """
   if building not in self.partitions.keys():
     raise ValueError("invalid building")
   floorplan = np.load(f"./{building}/tabular/floorplan.npy")

   def gdrive_to_direct_url(share_url):
        file_id = share_url.split('/d/')[1].split('/')[0]
        return f"https://drive.google.com/uc?export=download&id={file_id}"
   share_url = "https://drive.google.com/file/d/19W4exC1IfIpx6x_agZy3HO1ARXdxKnic/view?usp=sharing"
   direct_url = gdrive_to_direct_url(share_url)
   response = requests.get(direct_url)
   device_layout_map = response.json()

   return floorplan, device_layout_map


 def get_building_data(self, building, partition):
   """Gets the data for a specific building and partition.


   Args:
     building: The name of the building.
     partition: The name of the partition.


   Returns:
     A tuple containing the data and metadata.
   """
   if building not in self.partitions.keys():
     raise ValueError("invalid building")
   if partition not in self.partitions[building]:
     raise ValueError("invalid partition")
   path = f"./{building}/tabular/{building}/{partition}/"


   data = np.load(path + "data.npy.npz")
   metadata = pickle.load(open(path + "metadata.pickle", "rb"))


   if "device_infos" not in metadata.keys():
     metadata["device_infos"] = pickle.load(
         open(f"./{building}/tabular/device_info_dicts.pickle", "rb")
     )
   if "zone_infos" not in metadata.keys():
     metadata["zone_infos"] = pickle.load(
         open(f"./{building}/tabular/zone_info_dicts.pickle", "rb")
     )
   return data, metadata

# %%
#@title Data download and splitting

ds = SmartBuildingsDataset()

# training data: Jan-June 2022
data, metadata = ds.get_building_data("sb1","2022_a")
floorplan, device_layout_map = ds.get_floorplan("sb1")

# validation data: July-December 2022
data_val, metadata_val = ds.get_building_data("sb1","2022_b")
floorplan_val, device_layout_map_val = ds.get_floorplan("sb1")

# lets split validation data into things to predict, and exogenous variables
indexes = [v for k, v in metadata_val['observation_ids'].items() if "zone_air_temperature_sensor" in k]
temp_data = data_val['observation_value_matrix'][:, indexes]
matching_items = [(k, v) for k, v in metadata_val['observation_ids'].items() if "zone_air_temperature_sensor" in k]
temp_data_ids = {k: i for i, (k, v) in enumerate(matching_items)}

indexes = [v for k, v in metadata_val['observation_ids'].items() if "zone_air_temperature_sensor" not in k]
exogenous_observation_data = data_val['observation_value_matrix'][:, indexes]
matching_items = [(k, v) for k, v in metadata_val['observation_ids'].items() if "zone_air_temperature_sensor" not in k]
exogenous_observation_data_ids = {k: i for i, (k, v) in enumerate(matching_items)}

initial_condition = temp_data[0]
# Out:
# Downloading data...

# %% [markdown]
# #### 基础数据

# %%
# Train data:
data['observation_value_matrix']
metadata["observation_ids"]
metadata["observation_timestamps"]

data['action_value_matrix']
metadata["action_ids"]

floorplan
device_layout_map
metadata["device_infos"]

# Validation data:
data_val['action_value_matrix']
metadata_val["action_ids"]
metadata_val["observation_timestamps"]
floorplan
device_layout_map

exogenous_observation_data
exogenous_observation_data_ids
initial_condition

# Predict:
temp_data
temp_data_ids
# Out:
# {'2760348383893915@zone_air_temperature_sensor': 0,
#  '2562701969438717@zone_air_temperature_sensor': 1,
#  '2806035809406684@zone_air_temperature_sensor': 2,
#  '2790439929052995@zone_air_temperature_sensor': 3,
#  '2628534928204590@zone_air_temperature_sensor': 4,
#  '2535333053617205@zone_air_temperature_sensor': 5,
#  '2619255661594253@zone_air_temperature_sensor': 6,
#  '2618781414146613@zone_air_temperature_sensor': 7,
#  '2613654138967436@zone_air_temperature_sensor': 8,
#  '2762982574975969@zone_air_temperature_sensor': 9,
#  '2578499186529204@zone_air_temperature_sensor': 10,
#  '2693289483686059@zone_air_temperature_sensor': 11,
#  '2549483694528743@zone_air_temperature_sensor': 12,
#  '2614466029028994@zone_air_temperature_sensor': 13,
#  '2760979770441910@zone_air_temperature_sensor': 14,
#  '2732460999450017@zone_air_temperature_sensor': 15,
#  '2549513081490212@zone_air_temperature_sensor': 16,
#  '2737293899563066@zone_air_temperature_sensor': 17,
#  '2710040674126014@zone_air_temperature_sensor': 18,
#  '2570355700484963@zone_air_temperature_sensor': 19,
#  '2779591174908667@zone_air_temperature_sensor': 20,
#  '2768768486087571@zone_air_temperature_sensor': 21,
#  '2810271246509820@zone_air_temperature_sensor': 22,
#  '2705858092749449@zone_air_temperature_sensor': 23,
#  '2693840961422865@zone_air_temperature_sensor': 24,
#  '2740082748651605@zone_air_temperature_sensor': 25,
#  '2802781341872564@zone_air_temperature_sensor': 26,
#  '2568004980110825@zone_air_temperature_sensor': 27,
#  '2791846410789505@zone_air_temperature_sensor': 28,
#  '2651420801112308@zone_air_temperature_sensor': 29,
#  '2792140000757803@zone_air_temperature_sensor': 30,
#  '2788179547754974@zone_air_temperature_sensor': 31,
#  '2747395873491002@zone_air_temperature_sensor': 32,
#  '2618581107144046@zone_air_temperature_sensor': 33,
#  '2656676039327836@zone_air_temperature_sensor': 34,
#  '2794597849078830@zone_air_temperature_sensor': 35,
#  '2601599180090084@zone_air_temperature_sensor': 36,
#  '2546477821573302@zone_air_temperature_sensor': 37,
#  '2743847121700440@zone_air_temperature_sensor': 38,
#  '2803088381116360@zone_air_temperature_sensor': 39,
#  '2731964581915812@zone_air_temperature_sensor': 40,
#  '2684239960710884@zone_air_temperature_sensor': 41,
#  '2786928005384747@zone_air_temperature_sensor': 42,
#  '2584468317047883@zone_air_temperature_sensor': 43,
#  '2687242320524339@zone_air_temperature_sensor': 44,
#  '2612620611294283@zone_air_temperature_sensor': 45,
#  '2580539066022773@zone_air_temperature_sensor': 46,
#  '2691496710334693@zone_air_temperature_sensor': 47,
#  '2764530915698643@zone_air_temperature_sensor': 48,
#  '2658280459967125@zone_air_temperature_sensor': 49,
#  '2641439892024140@zone_air_temperature_sensor': 50,
#  '2795032460499273@zone_air_temperature_sensor': 51,
#  '2696593986887004@zone_air_temperature_sensor': 52,
#  '2728593088050266@zone_air_temperature_sensor': 53,
#  '2545072728476481@zone_air_temperature_sensor': 54,
#  '2588159730413024@zone_air_temperature_sensor': 55,
#  '2619215732412810@zone_air_temperature_sensor': 56,
#  '2812366126877759@zone_air_temperature_sensor': 57,
#  '2752553640836480@zone_air_temperature_sensor': 58,
#  '2578850932476951@zone_air_temperature_sensor': 59,
#  '2613479607618585@zone_air_temperature_sensor': 60,
#  '2725518459642243@zone_air_temperature_sensor': 61,
#  '2782657836669444@zone_air_temperature_sensor': 62,
#  '2739555701122103@zone_air_temperature_sensor': 63,
#  '2786127182232356@zone_air_temperature_sensor': 64,
#  '2607380776570984@zone_air_temperature_sensor': 65,
#  '2811944693103115@zone_air_temperature_sensor': 66,
#  '2627283060405570@zone_air_temperature_sensor': 67,
#  '2558614727946404@zone_air_temperature_sensor': 68,
#  '2680684754684585@zone_air_temperature_sensor': 69,
#  '2607531467124107@zone_air_temperature_sensor': 70,
#  '2656411871653032@zone_air_temperature_sensor': 71,
#  '2603432823050217@zone_air_temperature_sensor': 72,
#  '2684906181773151@zone_air_temperature_sensor': 73,
#  '2590610591373965@zone_air_temperature_sensor': 74,
#  '2776979270669786@zone_air_temperature_sensor': 75,
#  '2622037806906769@zone_air_temperature_sensor': 76,
#  '2560929853112707@zone_air_temperature_sensor': 77,
#  '2703938812282949@zone_air_temperature_sensor': 78,
#  '2580869304551907@zone_air_temperature_sensor': 79,
#  '2599277484308959@zone_air_temperature_sensor': 80,
#  '2792898514969792@zone_air_temperature_sensor': 81,
#  '2726572904605154@zone_air_temperature_sensor': 82,
#  '2605375500053318@zone_air_temperature_sensor': 83,
#  '2734562572216344@zone_air_temperature_sensor': 84,
#  '2715399727027143@zone_air_temperature_sensor': 85,
#  '2746959064186014@zone_air_temperature_sensor': 86,
#  '2698594043420456@zone_air_temperature_sensor': 87,
#  '2779757898406144@zone_air_temperature_sensor': 88,
#  '2667818838237334@zone_air_temperature_sensor': 89,
#  '2577372819803107@zone_air_temperature_sensor': 90,
#  '2657554847589841@zone_air_temperature_sensor': 91,
#  '2736579912341782@zone_air_temperature_sensor': 92,
#  '2703995402831823@zone_air_temperature_sensor': 93,
#  '2758068039436455@zone_air_temperature_sensor': 94,
#  '2712344453081531@zone_air_temperature_sensor': 95,
#  '2555387941965464@zone_air_temperature_sensor': 96,
#  '2683563351071572@zone_air_temperature_sensor': 97,
#  '2706839052470546@zone_air_temperature_sensor': 98,
#  '2749879183751781@zone_air_temperature_sensor': 99,
#  '2620112368775269@zone_air_temperature_sensor': 100,
#  '2807442344300820@zone_air_temperature_sensor': 101,
#  '2806531358805482@zone_air_temperature_sensor': 102,
#  '2674020841435318@zone_air_temperature_sensor': 103,
#  '2590087554896009@zone_air_temperature_sensor': 104,
#  '2618254258255786@zone_air_temperature_sensor': 105,
#  '2787448836354673@zone_air_temperature_sensor': 106,
#  '2717096440251637@zone_air_temperature_sensor': 107,
#  '16286830034440683520@zone_air_temperature_sensor': 108,
#  '2578744141471091@zone_air_temperature_sensor': 109,
#  '2657144210326005@zone_air_temperature_sensor': 110,
#  '2720359073646091@zone_air_temperature_sensor': 111,
#  '2766271641619615@zone_air_temperature_sensor': 112,
#  '2696383178287941@zone_air_temperature_sensor': 113,
#  '2591831048896702@zone_air_temperature_sensor': 114,
#  '2538526995118004@zone_air_temperature_sensor': 115,
#  '2651594506537727@zone_air_temperature_sensor': 116,
#  '2696614388023593@zone_air_temperature_sensor': 117,
#  '2720149542779272@zone_air_temperature_sensor': 118,
#  '2805009894538456@zone_air_temperature_sensor': 119,
#  '2559962019321287@zone_air_temperature_sensor': 120,
#  '2606839440408366@zone_air_temperature_sensor': 121,
#  '2640423556868160@zone_air_temperature_sensor': 122}

# %%
from matplotlib import pyplot as plt
plt.imshow(floorplan, interpolation='nearest')
plt.show()

# %%
metadata["device_infos"][0]
# Out:
# {'device_id': '202194278473007104',
#  'namespace': 'PHRED',
#  'code': 'SB1:AHU:AC-2',
#  'zone_id': '',
#  'device_type': 6,
#  'observable_fields': {'building_air_static_pressure_sensor': 1,
#   'outside_air_flowrate_sensor': 1,
#   'supply_fan_speed_percentage_command': 1,
#   'supply_air_temperature_sensor': 1,
#   'supply_fan_speed_frequency_sensor': 1,
#   'supply_air_static_pressure_setpoint': 1,
#   'return_air_temperature_sensor': 1,
#   'mixed_air_temperature_setpoint': 1,
#   'exhaust_fan_speed_percentage_command': 1,
#   'exhaust_fan_speed_frequency_sensor': 1,
#   'outside_air_damper_percentage_command': 1,
#   'mixed_air_temperature_sensor': 1,
#   'exhaust_air_damper_percentage_command': 1,
#   'cooling_percentage_command': 1,
#   'outside_air_flowrate_setpoint': 1,
#   'supply_air_temperature_setpoint': 1,
#   'building_air_static_pressure_setpoint': 1,
#   'supply_air_static_pressure_sensor': 1},
#  'action_fields': {'exhaust_air_damper_percentage_command': 1,
#   'supply_air_temperature_setpoint': 1,
#   'supply_fan_speed_percentage_command': 1,
#   'outside_air_flowrate_setpoint': 1,
#   'cooling_percentage_command': 1,
#   'mixed_air_temperature_setpoint': 1,
#   'exhaust_fan_speed_percentage_command': 1,
#   'outside_air_damper_percentage_command': 1,
#   'supply_air_static_pressure_setpoint': 1,
#   'building_air_static_pressure_setpoint': 1}}

# %%
metadata["zone_infos"][0]
# Out:
# {'zone_id': 'rooms/1002000133978',
#  'building_id': 'buildings/3616672508',
#  'zone_description': 'SB1-2-C2054',
#  'area': 0.0,
#  'zone_type': 1,
#  'floor': 2,
#  'devices': ['2618581107144046', '2696593986887004']}

# %% [markdown]
# #### github库

# %%
pip install git+https://github.com/EURAC-EEBgroup/pybuildingcluster.git
# Out:
# Collecting git+https://github.com/EURAC-EEBgroup/pybuildingcluster.git
#   Cloning https://github.com/EURAC-EEBgroup/pybuildingcluster.git to /tmp/pip-req-build-fe8ru_ar
#   Running command git clone --filter=blob:none --quiet https://github.com/EURAC-EEBgroup/pybuildingcluster.git /tmp/pip-req-build-fe8ru_ar
#   Resolved https://github.com/EURAC-EEBgroup/pybuildingcluster.git to commit 578d8bfc435d50d4b9aafac24ae62450105aa3d9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pybuildingcluster==1.0.8) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pybuildingcluster==1.0.8) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from pybuildingcluster==1.0.8) (5.24.1)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from pybuildingcluster==1.0.8) (2.11.7)
# Requirement already satisfied: pydantic_core in /usr/local/lib/python3.11/dist-packages (from pybuildingcluster==1.0.8) (2.33.2)
# Collecting python-dotenv (from pybuildingcluster==1.0.8)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from pybuildingcluster==1.0.8) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pybuildingcluster==1.0.8) (1.15.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from pybuildingcluster==1.0.8) (0.13.2)
# Collecting workalendar (from pybuildingcluster==1.0.8)
#   Downloading workalendar-17.0.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting gunicorn (from pybuildingcluster==1.0.8)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from pybuildingcluster==1.0.8) (2.18.0)
# Collecting optuna (from pybuildingcluster==1.0.8)
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pybuildingcluster==1.0.8) (3.10.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (from pybuildingcluster==1.0.8) (2.1.4)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (from pybuildingcluster==1.0.8) (4.5.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from pybuildingcluster==1.0.8) (1.5.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (from pybuildingcluster==1.0.8) (7.7.1)
# Collecting jupyter (from pybuildingcluster==1.0.8)
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from gunicorn->pybuildingcluster==1.0.8) (24.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->pybuildingcluster==1.0.8) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->pybuildingcluster==1.0.8) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->pybuildingcluster==1.0.8) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->pybuildingcluster==1.0.8) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->pybuildingcluster==1.0.8) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->pybuildingcluster==1.0.8) (3.0.15)
# Requirement already satisfied: notebook in /usr/local/lib/python3.11/dist-packages (from jupyter->pybuildingcluster==1.0.8) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.11/dist-packages (from jupyter->pybuildingcluster==1.0.8) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.11/dist-packages (from jupyter->pybuildingcluster==1.0.8) (7.16.6)
# Collecting jupyterlab (from jupyter->pybuildingcluster==1.0.8)
#   Downloading jupyterlab-4.4.4-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pybuildingcluster==1.0.8) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pybuildingcluster==1.0.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pybuildingcluster==1.0.8) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pybuildingcluster==1.0.8) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pybuildingcluster==1.0.8) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pybuildingcluster==1.0.8) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pybuildingcluster==1.0.8) (2.9.0.post0)
# Collecting alembic>=1.5.0 (from optuna->pybuildingcluster==1.0.8)
#   Downloading alembic-1.16.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna->pybuildingcluster==1.0.8)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->pybuildingcluster==1.0.8) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna->pybuildingcluster==1.0.8) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna->pybuildingcluster==1.0.8) (6.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pybuildingcluster==1.0.8) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pybuildingcluster==1.0.8) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->pybuildingcluster==1.0.8) (8.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->pybuildingcluster==1.0.8) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->pybuildingcluster==1.0.8) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->pybuildingcluster==1.0.8) (0.4.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pybuildingcluster==1.0.8) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->pybuildingcluster==1.0.8) (0.37.1)
# Collecting lunardate (from workalendar->pybuildingcluster==1.0.8)
#   Downloading lunardate-0.2.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting convertdate (from workalendar->pybuildingcluster==1.0.8)
#   Downloading convertdate-2.4.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting pyluach (from workalendar->pybuildingcluster==1.0.8)
#   Downloading pyluach-2.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost->pybuildingcluster==1.0.8) (2.21.5)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->pybuildingcluster==1.0.8) (1.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->pybuildingcluster==1.0.8) (0.45.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->pybuildingcluster==1.0.8) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->pybuildingcluster==1.0.8) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->pybuildingcluster==1.0.8) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->pybuildingcluster==1.0.8) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->pybuildingcluster==1.0.8) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->pybuildingcluster==1.0.8) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->pybuildingcluster==1.0.8) (6.4.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->pybuildingcluster==1.0.8)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->pybuildingcluster==1.0.8) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->pybuildingcluster==1.0.8) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->pybuildingcluster==1.0.8) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->pybuildingcluster==1.0.8) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->pybuildingcluster==1.0.8) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->pybuildingcluster==1.0.8) (4.9.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->pybuildingcluster==1.0.8) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->pybuildingcluster==1.0.8) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->pybuildingcluster==1.0.8) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->pybuildingcluster==1.0.8) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->pybuildingcluster==1.0.8) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->pybuildingcluster==1.0.8) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->pybuildingcluster==1.0.8) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->pybuildingcluster==1.0.8) (3.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->pybuildingcluster==1.0.8) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->pybuildingcluster==1.0.8) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->pybuildingcluster==1.0.8) (3.1.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter->pybuildingcluster==1.0.8) (3.1.6)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter->pybuildingcluster==1.0.8) (25.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter->pybuildingcluster==1.0.8) (5.8.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter->pybuildingcluster==1.0.8) (5.10.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter->pybuildingcluster==1.0.8) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter->pybuildingcluster==1.0.8) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter->pybuildingcluster==1.0.8) (0.22.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter->pybuildingcluster==1.0.8) (1.3.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter->pybuildingcluster==1.0.8) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->pybuildingcluster==1.0.8) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter->pybuildingcluster==1.0.8) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter->pybuildingcluster==1.0.8) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter->pybuildingcluster==1.0.8) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter->pybuildingcluster==1.0.8) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter->pybuildingcluster==1.0.8) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter->pybuildingcluster==1.0.8) (1.5.1)
# Collecting pymeeus<=1,>=0.3.13 (from convertdate->workalendar->pybuildingcluster==1.0.8)
#   Downloading PyMeeus-0.5.12.tar.gz (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 92.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter->pybuildingcluster==1.0.8) (0.28.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading jupyter_server-2.16.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter->pybuildingcluster==1.0.8) (0.2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->pybuildingcluster==1.0.8) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->pybuildingcluster==1.0.8) (1.4.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->pybuildingcluster==1.0.8) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->pybuildingcluster==1.0.8) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->pybuildingcluster==1.0.8) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->pybuildingcluster==1.0.8) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.1->notebook->jupyter->pybuildingcluster==1.0.8) (4.3.8)
# Collecting jupyter-client>=6.1.12 (from ipykernel>=4.5.1->ipywidgets->pybuildingcluster==1.0.8)
#   Downloading jupyter_client-7.4.9-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pybuildingcluster==1.0.8) (1.8.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook->jupyter->pybuildingcluster==1.0.8) (21.2.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pybuildingcluster==1.0.8) (0.4)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pybuildingcluster==1.0.8) (2.17.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading json5-0.12.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pybuildingcluster==1.0.8) (4.24.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook->jupyter->pybuildingcluster==1.0.8) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->pybuildingcluster==1.0.8) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->pybuildingcluster==1.0.8) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert->jupyter->pybuildingcluster==1.0.8) (2.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow->pybuildingcluster==1.0.8) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter->pybuildingcluster==1.0.8) (1.3.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pybuildingcluster==1.0.8) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pybuildingcluster==1.0.8) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pybuildingcluster==1.0.8) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pybuildingcluster==1.0.8) (0.26.0)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading python_json_logger-3.3.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->pybuildingcluster==1.0.8) (0.1.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->pybuildingcluster==1.0.8) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->pybuildingcluster==1.0.8) (2.22)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pybuildingcluster==1.0.8) (3.0.0)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pybuildingcluster==1.0.8) (24.11.1)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pybuildingcluster==1.0.8)
#   Downloading types_python_dateutil-2.9.0.20250516-py3-none-any.whl.metadata (2.1 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 8.2 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 31.0 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading workalendar-17.0.0-py3-none-any.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 18.5 MB/s eta 0:00:00
# Downloading alembic-1.16.2-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 24.6 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 4.3 MB/s eta 0:00:00
# Downloading jupyterlab-4.4.4-py3-none-any.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 127.6 MB/s eta 0:00:00
# Downloading lunardate-0.2.2-py3-none-any.whl (18 kB)
# Downloading pyluach-2.2.0-py3-none-any.whl (25 kB)
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.0 MB/s eta 0:00:00
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 6.4 MB/s eta 0:00:00
# Downloading jupyter_server-2.16.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 32.3 MB/s eta 0:00:00
# Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 12.9 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 5.3 MB/s eta 0:00:00
# Downloading json5-0.12.0-py3-none-any.whl (36 kB)
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.9 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20250516-py3-none-any.whl (14 kB)
# Building wheels for collected packages: pybuildingcluster, pymeeus
#   Building wheel for pybuildingcluster (setup.py) ... done
#   Created wheel for pybuildingcluster: filename=pybuildingcluster-1.0.8-py3-none-any.whl size=82845 sha256=27c05ca8ce4a0bb4b9705da4f831f414d0dc952d6e2d3f3c9e55cf3537cd8049
#   Stored in directory: /tmp/pip-ephem-wheel-cache-eyj3oyrt/wheels/02/07/36/78d72848ee8898ffce6f4214ab88a08c82714166583d93fbb6
#   Building wheel for pymeeus (setup.py) ... done
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=732000 sha256=0a3183eca3d4b5cb6946aeac8b0a1e13e88996ca050636f19543736c4c379f4d
#   Stored in directory: /root/.cache/pip/wheels/8f/bd/f9/5c4c39b529e0322b08979e1c465e203218bc2cca75d20f7df5
# Successfully built pybuildingcluster pymeeus
# Installing collected packages: pymeeus, lunardate, uri-template, types-python-dateutil, rfc3986-validator, rfc3339-validator, python-json-logger, python-dotenv, pyluach, overrides, json5, jedi, gunicorn, fqdn, convertdate, colorlog, async-lru, workalendar, jupyter-server-terminals, jupyter-client, arrow, alembic, optuna, isoduration, jupyter-events, jupyter-server, jupyterlab-server, jupyter-lsp, jupyterlab, jupyter, pybuildingcluster
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.16.0
#     Uninstalling jupyter-server-1.16.0:
#       Successfully uninstalled jupyter-server-1.16.0
# Successfully installed alembic-1.16.2 arrow-1.3.0 async-lru-2.0.5 colorlog-6.9.0 convertdate-2.4.0 fqdn-1.5.1 gunicorn-23.0.0 isoduration-20.11.0 jedi-0.19.2 json5-0.12.0 jupyter-1.1.1 jupyter-client-7.4.9 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.16.0 jupyter-server-terminals-0.5.3 jupyterlab-4.4.4 jupyterlab-server-2.27.3 lunardate-0.2.2 optuna-4.4.0 overrides-7.7.0 pybuildingcluster-1.0.8 pyluach-2.2.0 pymeeus-0.5.12 python-dotenv-1.1.1 python-json-logger-3.3.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 types-python-dateutil-2.9.0.20250516 uri-template-1.3.0 workalendar-17.0.0

# %% [markdown]
# ##### 训练

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
from pybuildingcluster import RegressionModelBuilder

# —— 1. 从训练集提取外生变量和温度目标（假设data和metadata已准备好）

# 训练集目标变量索引（所有温度传感器）
indexes_train_target = [v for k, v in metadata['observation_ids'].items() if "zone_air_temperature_sensor" in k]
train_target_all = data['observation_value_matrix'][:, indexes_train_target]

# 训练集外生变量索引（非温度传感器）
indexes_train_exogenous = [v for k, v in metadata['observation_ids'].items() if "zone_air_temperature_sensor" not in k]
train_exogenous = data['observation_value_matrix'][:, indexes_train_exogenous]

# —— 2. 选择一个温度传感器作为预测目标（这里以第0个为例）——————————————————————————————————————————————————————————
target_sensor_index = 0
y_train = train_target_all[:, target_sensor_index]
X_train = train_exogenous

# —— 3. 构造训练 DataFrame
feature_names = [f'feature_{i}' for i in range(X_train.shape[1])]
df_train = pd.DataFrame(X_train, columns=feature_names)
df_train['target_temp'] = y_train
df_train['cluster'] = 0  # 添加cluster列，必需

# —— 4. 初始化模型构建器，训练模型
builder = RegressionModelBuilder(random_state=42, problem_type="regression")




# 实现训练过程可视化，你需要绕开 build_models()，直接用 LightGBM（或其他模型）官方API训练

from lightgbm import LGBMRegressor, early_stopping, log_evaluation
import matplotlib.pyplot as plt

X_train_np = df_train[feature_names].values
y_train_np = df_train['target_temp'].values

model = LGBMRegressor(n_estimators=100, random_state=42)

model.fit(
    X_train_np, y_train_np,
    eval_set=[(X_train_np, y_train_np)],
    eval_metric='rmse',
    callbacks=[early_stopping(stopping_rounds=10), log_evaluation(period=10)]
)

evals_result = model.evals_result_

train_rmse = evals_result['training']['rmse']

plt.plot(train_rmse)
plt.title("Training RMSE")
plt.xlabel("Iteration")
plt.ylabel("RMSE")
plt.show()




'''models = builder.build_models(
    data=df_train,
    clusters=df_train,
    target_column='target_temp',
    feature_columns=feature_names,
    models_to_train=['lightgbm'],  # 你也可以加 'random_forest','xgboost' 等
    hyperparameter_tuning="none",
    save_models=False
)
model = models[0]['best_model']'''
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.296951 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.778735
# Training until validation scores don't improve for 10 rounds
# [10]	training's rmse: 10.9934	training's l2: 120.856
# [20]	training's rmse: 3.84458	training's l2: 14.7808
# [30]	training's rmse: 1.36174	training's l2: 1.85433
# [40]	training's rmse: 0.518279	training's l2: 0.268613
# [50]	training's rmse: 0.260369	training's l2: 0.0677919
# [60]	training's rmse: 0.196224	training's l2: 0.0385037
# [70]	training's rmse: 0.177088	training's l2: 0.0313602
# [80]	training's rmse: 0.166682	training's l2: 0.0277827
# [90]	training's rmse: 0.158947	training's l2: 0.0252641
# [100]	training's rmse: 0.15314	training's l2: 0.0234517
# 'models = builder.build_models(\n    data=df_train,\n    clusters=df_train,\n    target_column=\'target_temp\',\n    feature_columns=feature_names,\n    models_to_train=[\'lightgbm\'],  # 你也可以加 \'random_forest\',\'xgboost\' 等\n    hyperparameter_tuning="none",\n    save_models=False\n)\nmodel = models[0][\'best_model\']'

# %% [markdown]
# ##### 训练＋预测

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from lightgbm import LGBMRegressor

# —— 1. 提取训练数据
indexes_train_target = [v for k, v in metadata['observation_ids'].items() if "zone_air_temperature_sensor" in k]
train_target_all = data['observation_value_matrix'][:, indexes_train_target]

indexes_train_exogenous = [v for k, v in metadata['observation_ids'].items() if "zone_air_temperature_sensor" not in k]
train_exogenous = data['observation_value_matrix'][:, indexes_train_exogenous]

# —— 2. 提取验证数据
indexes_val_target = [v for k, v in metadata_val['observation_ids'].items() if "zone_air_temperature_sensor" in k]
val_target_all = data_val['observation_value_matrix'][:, indexes_val_target]

indexes_val_exogenous = [v for k, v in metadata_val['observation_ids'].items() if "zone_air_temperature_sensor" not in k]
val_exogenous = data_val['observation_value_matrix'][:, indexes_val_exogenous]

# —— 3. 训练每个传感器模型并评估
feature_names = [f'feature_{i}' for i in range(train_exogenous.shape[1])]
results = []

for i, sensor_index in enumerate(indexes_train_target):
    print(f"\n=== 训练第 {i+1}/{len(indexes_train_target)} 个温度传感器 ===")

    y_train = train_target_all[:, i]
    X_train = train_exogenous

    y_val = val_target_all[:, i]
    X_val = val_exogenous

    # 训练 LightGBM 模型
    model = LGBMRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    # 预测验证集
    y_pred = model.predict(X_val)

    # 评估指标
    mae = mean_absolute_error(y_val, y_pred)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    r2 = r2_score(y_val, y_pred)
    print(f"MAE: {mae:.2f}, RMSE: {rmse:.2f}, R²: {r2:.4f}")

    results.append({
        "sensor_index": sensor_index,
        "mae": mae,
        "rmse": rmse,
        "r2": r2,
        "y_true": y_val,
        "y_pred": y_pred
    })

    # 可视化前3个传感器的结果
    if i < 3:
        plt.figure(figsize=(12, 4))
        plt.plot(y_val, label="True")
        plt.plot(y_pred, label="Predicted", linestyle='--')
        plt.title(f"Sensor {sensor_index} - Predicted vs True")
        plt.xlabel("Time Step")
        plt.ylabel("Temperature (℉)")
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

# —— 4. 输出整体平均表现
avg_mae = np.mean([r["mae"] for r in results])
avg_rmse = np.mean([r["rmse"] for r in results])
avg_r2 = np.mean([r["r2"] for r in results])

print("\n=== 所有传感器平均表现 ===")
print(f"平均 MAE: {avg_mae:.2f}")
print(f"平均 RMSE: {avg_rmse:.2f}")
print(f"平均 R²: {avg_r2:.4f}")


import csv

# 汇总成列表字典，并使用重新编号的序号（从1到123）
summary = []
for idx, r in enumerate(results, start=1):  # 用 enumerate 自动编号
    summary.append({
        "sensor_id": idx,  # 新编号，从 1 开始
        "mae": r["mae"],
        "rmse": r["rmse"],
        "r2": r["r2"]
    })

# 转为DataFrame保存csv
df_summary = pd.DataFrame(summary)
df_summary.to_csv("sensor_performance_summary.csv", index=False)

print("结果已保存到 sensor_performance_summary.csv")
# Out:
# === 训练第 1/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.226151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.778735
# MAE: 1.35, RMSE: 2.06, R²: 0.9910
# === 训练第 2/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223258 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.460207
# MAE: 0.88, RMSE: 1.59, R²: 0.9946
# === 训练第 3/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.237819 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.140017
# MAE: 1.40, RMSE: 1.96, R²: 0.9915
# === 训练第 4/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.348432 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.961340
# MAE: 0.78, RMSE: 1.06, R²: 0.9975
#
# === 训练第 5/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.235302 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.248538
# MAE: 0.72, RMSE: 1.14, R²: 0.9972
#
# === 训练第 6/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.224469 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.251783
# MAE: 0.82, RMSE: 1.23, R²: 0.9969
#
# === 训练第 7/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223840 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.284278
# MAE: 1.46, RMSE: 2.51, R²: 0.9869
#
# === 训练第 8/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.304289 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.116986
# MAE: 1.09, RMSE: 1.60, R²: 0.9947
#
# === 训练第 9/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223556 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.051616
# MAE: 1.32, RMSE: 1.88, R²: 0.9920
#
# === 训练第 10/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.225368 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.901706
# MAE: 0.57, RMSE: 0.82, R²: 0.9986
#
# === 训练第 11/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.311938 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.924271
# MAE: 1.40, RMSE: 1.93, R²: 0.9919
#
# === 训练第 12/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.231996 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.656715
# MAE: 0.61, RMSE: 0.84, R²: 0.9985
#
# === 训练第 13/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.220617 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.663384
# MAE: 0.75, RMSE: 1.09, R²: 0.9975
#
# === 训练第 14/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.224596 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.678361
# MAE: 2.08, RMSE: 2.74, R²: 0.9831
#
# === 训练第 15/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.301948 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 51.056121
# MAE: 1.04, RMSE: 1.64, R²: 0.9945
#
# === 训练第 16/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.221081 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.358003
# MAE: 1.27, RMSE: 1.88, R²: 0.9927
#
# === 训练第 17/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.226943 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.922799
# MAE: 1.44, RMSE: 2.14, R²: 0.9900
#
# === 训练第 18/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.255456 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.060996
# MAE: 1.17, RMSE: 1.56, R²: 0.9944
#
# === 训练第 19/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.236197 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.740582
# MAE: 1.17, RMSE: 1.87, R²: 0.9923
#
# === 训练第 20/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.229324 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.305226
# MAE: 0.90, RMSE: 1.34, R²: 0.9960
#
# === 训练第 21/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.225832 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.805363
# MAE: 2.53, RMSE: 3.11, R²: 0.9784
#
# === 训练第 22/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.291319 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 46.718458
# MAE: 1.11, RMSE: 1.54, R²: 0.9946
#
# === 训练第 23/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.222855 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.638314
# MAE: 0.74, RMSE: 1.05, R²: 0.9975
#
# === 训练第 24/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223686 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.149610
# MAE: 1.05, RMSE: 1.63, R²: 0.9942
#
# === 训练第 25/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.220828 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.121169
# MAE: 1.08, RMSE: 1.61, R²: 0.9942
#
# === 训练第 26/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.283395 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.947919
# MAE: 0.74, RMSE: 1.14, R²: 0.9970
#
# === 训练第 27/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223336 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 47.931447
# MAE: 0.90, RMSE: 1.26, R²: 0.9965
#
# === 训练第 28/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.231207 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.966145
# MAE: 1.42, RMSE: 1.88, R²: 0.9924
#
# === 训练第 29/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.230620 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.987907
# MAE: 1.02, RMSE: 1.66, R²: 0.9939
#
# === 训练第 30/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.293297 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.333747
# MAE: 0.66, RMSE: 0.99, R²: 0.9979
#
# === 训练第 31/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.229371 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.034162
# MAE: 0.80, RMSE: 1.15, R²: 0.9973
#
# === 训练第 32/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223103 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.726776
# MAE: 0.79, RMSE: 1.14, R²: 0.9971
#
# === 训练第 33/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.247750 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.575092
# MAE: 1.14, RMSE: 1.71, R²: 0.9936
#
# === 训练第 34/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.224349 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.769035
# MAE: 1.54, RMSE: 2.26, R²: 0.9887
#
# === 训练第 35/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.221910 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 47.553068
# MAE: 0.87, RMSE: 1.32, R²: 0.9961
#
# === 训练第 36/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.222283 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.948192
# MAE: 1.05, RMSE: 1.56, R²: 0.9949
#
# === 训练第 37/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.262728 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.418969
# MAE: 1.14, RMSE: 1.72, R²: 0.9934
#
# === 训练第 38/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.232679 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.190592
# MAE: 1.15, RMSE: 1.64, R²: 0.9943
#
# === 训练第 39/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223316 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.347590
# MAE: 1.02, RMSE: 1.49, R²: 0.9955
#
# === 训练第 40/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.221660 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.210269
# MAE: 1.42, RMSE: 2.02, R²: 0.9908
#
# === 训练第 41/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.250789 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.442272
# MAE: 1.21, RMSE: 1.75, R²: 0.9936
#
# === 训练第 42/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.285380 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 51.465127
# MAE: 1.94, RMSE: 2.41, R²: 0.9874
#
# === 训练第 43/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.246862 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 47.797211
# MAE: 0.91, RMSE: 1.26, R²: 0.9964
#
# === 训练第 44/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.236874 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.093753
# MAE: 1.12, RMSE: 1.67, R²: 0.9939
#
# === 训练第 45/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.254264 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.418010
# MAE: 1.42, RMSE: 2.12, R²: 0.9902
#
# === 训练第 46/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.226200 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.970907
# MAE: 0.83, RMSE: 1.22, R²: 0.9967
#
# === 训练第 47/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.225163 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.800835
# MAE: 0.94, RMSE: 1.41, R²: 0.9955
#
# === 训练第 48/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.221797 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.985821
# MAE: 1.25, RMSE: 1.89, R²: 0.9924
#
# === 训练第 49/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.316037 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.711787
# MAE: 0.89, RMSE: 1.29, R²: 0.9963
#
# === 训练第 50/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.243875 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.535321
# MAE: 0.74, RMSE: 1.07, R²: 0.9974
#
# === 训练第 51/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.229663 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.282243
# MAE: 1.51, RMSE: 1.98, R²: 0.9912
#
# === 训练第 52/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.251357 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.460138
# MAE: 1.03, RMSE: 1.56, R²: 0.9949
#
# === 训练第 53/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.222489 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.671208
# MAE: 1.93, RMSE: 2.41, R²: 0.9874
#
# === 训练第 54/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223045 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.664252
# MAE: 1.45, RMSE: 2.29, R²: 0.9895
#
# === 训练第 55/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.229099 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.341583
# MAE: 0.84, RMSE: 1.22, R²: 0.9966
#
# === 训练第 56/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.252742 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.267727
# MAE: 0.57, RMSE: 0.82, R²: 0.9985
#
# === 训练第 57/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.226383 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.380739
# MAE: 1.14, RMSE: 1.77, R²: 0.9934
#
# === 训练第 58/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223196 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.375908
# MAE: 1.06, RMSE: 1.53, R²: 0.9948
#
# === 训练第 59/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223189 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.361228
# MAE: 1.32, RMSE: 1.80, R²: 0.9930
#
# === 训练第 60/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.287652 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.290320
# MAE: 0.95, RMSE: 1.36, R²: 0.9961
#
# === 训练第 61/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.221358 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.566934
# MAE: 1.00, RMSE: 1.30, R²: 0.9964
#
# === 训练第 62/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223962 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.447772
# MAE: 1.18, RMSE: 1.83, R²: 0.9927
#
# === 训练第 63/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.249695 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 51.342787
# MAE: 0.63, RMSE: 0.96, R²: 0.9981
#
# === 训练第 64/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.226241 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.986052
# MAE: 1.31, RMSE: 1.93, R²: 0.9920
#
# === 训练第 65/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.234978 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 47.647678
# MAE: 0.87, RMSE: 1.27, R²: 0.9964
#
# === 训练第 66/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223942 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.372194
# MAE: 0.97, RMSE: 1.73, R²: 0.9934
#
# === 训练第 67/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.243715 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.201556
# MAE: 0.91, RMSE: 1.36, R²: 0.9960
#
# === 训练第 68/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.240233 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.854732
# MAE: 1.18, RMSE: 1.67, R²: 0.9943
#
# === 训练第 69/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.222886 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.261098
# MAE: 1.46, RMSE: 1.98, R²: 0.9916
#
# === 训练第 70/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.225081 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.930353
# MAE: 0.79, RMSE: 1.23, R²: 0.9968
#
# === 训练第 71/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.318790 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 47.973864
# MAE: 1.06, RMSE: 1.56, R²: 0.9947
#
# === 训练第 72/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.233819 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.425941
# MAE: 0.70, RMSE: 1.11, R²: 0.9988
#
# === 训练第 73/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.236636 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.099868
# MAE: 1.03, RMSE: 1.47, R²: 0.9954
#
# === 训练第 74/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.237702 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 51.105403
# MAE: 0.48, RMSE: 0.71, R²: 0.9990
#
# === 训练第 75/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.331079 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.359099
# MAE: 0.98, RMSE: 1.44, R²: 0.9954
#
# === 训练第 76/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.224048 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.508231
# MAE: 0.73, RMSE: 1.03, R²: 0.9977
#
# === 训练第 77/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.226296 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.177906
# MAE: 1.12, RMSE: 1.46, R²: 0.9952
#
# === 训练第 78/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.251596 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.048005
# MAE: 1.20, RMSE: 1.71, R²: 0.9936
#
# === 训练第 79/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.228527 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.590388
# MAE: 1.24, RMSE: 1.79, R²: 0.9931
#
# === 训练第 80/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.222224 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.734910
# MAE: 1.26, RMSE: 1.98, R²: 0.9913
#
# === 训练第 81/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.226029 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 51.132077
# MAE: 1.04, RMSE: 1.57, R²: 0.9949
#
# === 训练第 82/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.254942 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.819864
# MAE: 1.11, RMSE: 1.70, R²: 0.9936
#
# === 训练第 83/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.291668 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 51.128741
# MAE: 0.82, RMSE: 1.19, R²: 0.9970
#
# === 训练第 84/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.225870 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.097018
# MAE: 1.03, RMSE: 1.51, R²: 0.9949
#
# === 训练第 85/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.224706 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 47.376531
# MAE: 1.19, RMSE: 1.72, R²: 0.9933
#
# === 训练第 86/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.248632 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.252323
# MAE: 1.19, RMSE: 1.84, R²: 0.9924
#
# === 训练第 87/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.232583 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.091070
# MAE: 0.73, RMSE: 1.08, R²: 0.9975
#
# === 训练第 88/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.224121 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.121995
# MAE: 1.16, RMSE: 1.70, R²: 0.9937
#
# === 训练第 89/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.224908 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 51.500223
# MAE: 0.54, RMSE: 0.77, R²: 0.9987
#
# === 训练第 90/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.244955 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.676080
# MAE: 1.24, RMSE: 1.75, R²: 0.9936
#
# === 训练第 91/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.289828 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 51.432081
# MAE: 1.73, RMSE: 2.50, R²: 0.9872
#
# === 训练第 92/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223902 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.378816
# MAE: 0.99, RMSE: 1.36, R²: 0.9959
#
# === 训练第 93/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.224497 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.607149
# MAE: 1.08, RMSE: 1.70, R²: 0.9936
#
# === 训练第 94/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.259323 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.501559
# MAE: 1.52, RMSE: 2.08, R²: 0.9904
#
# === 训练第 95/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.248584 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.294173
# MAE: 1.34, RMSE: 1.91, R²: 0.9927
#
# === 训练第 96/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.228041 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.881102
# MAE: 1.02, RMSE: 1.56, R²: 0.9948
#
# === 训练第 97/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.225991 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 47.744185
# MAE: 1.03, RMSE: 1.42, R²: 0.9959
#
# === 训练第 98/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.262009 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.059044
# MAE: 1.05, RMSE: 1.56, R²: 0.9947
#
# === 训练第 99/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.227001 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.435813
# MAE: 1.37, RMSE: 2.05, R²: 0.9907
#
# === 训练第 100/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.236978 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 47.922080
# MAE: 0.82, RMSE: 1.19, R²: 0.9970
#
# === 训练第 101/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.222125 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.094156
# MAE: 1.45, RMSE: 2.37, R²: 0.9885
#
# === 训练第 102/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.222028 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.220989
# MAE: 1.12, RMSE: 1.81, R²: 0.9928
#
# === 训练第 103/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.282755 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.666354
# MAE: 1.16, RMSE: 1.81, R²: 0.9929
#
# === 训练第 104/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223216 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.395699
# MAE: 0.58, RMSE: 0.82, R²: 0.9986
#
# === 训练第 105/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.225019 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.910084
# MAE: 1.53, RMSE: 2.06, R²: 0.9917
#
# === 训练第 106/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.243267 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.243152
# MAE: 0.85, RMSE: 1.15, R²: 0.9971
#
# === 训练第 107/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.300387 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.287177
# MAE: 1.39, RMSE: 1.92, R²: 0.9916
#
# === 训练第 108/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.222811 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.503590
# MAE: 0.88, RMSE: 1.27, R²: 0.9965
#
# === 训练第 109/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223188 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 211.420320
# MAE: 0.22, RMSE: 0.34, R²: 1.0000
#
# === 训练第 110/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.244940 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 47.029570
# MAE: 0.90, RMSE: 1.35, R²: 0.9958
#
# === 训练第 111/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.293377 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.223040
# MAE: 0.99, RMSE: 1.43, R²: 0.9958
#
# === 训练第 112/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.227684 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.805195
# MAE: 1.04, RMSE: 1.47, R²: 0.9954
#
# === 训练第 113/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.225723 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.597888
# MAE: 1.05, RMSE: 1.59, R²: 0.9944
#
# === 训练第 114/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.247296 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.581129
# MAE: 0.94, RMSE: 1.39, R²: 0.9957
#
# === 训练第 115/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.283220 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 51.476367
# MAE: 1.39, RMSE: 1.95, R²: 0.9919
#
# === 训练第 116/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.224102 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.878024
# MAE: 0.78, RMSE: 1.14, R²: 0.9970
#
# === 训练第 117/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.223674 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.510757
# MAE: 0.68, RMSE: 0.99, R²: 0.9979
#
# === 训练第 118/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.225985 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 49.384692
# MAE: 0.98, RMSE: 1.40, R²: 0.9958
#
# === 训练第 119/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.323681 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 51.326600
# MAE: 1.17, RMSE: 1.68, R²: 0.9940
#
# === 训练第 120/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.222632 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 51.397654
# MAE: 0.54, RMSE: 0.79, R²: 0.9987
#
# === 训练第 121/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.220742 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 48.442656
# MAE: 1.25, RMSE: 1.89, R²: 0.9919
#
# === 训练第 122/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.238558 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.792436
# MAE: 2.41, RMSE: 2.92, R²: 0.9806
#
# === 训练第 123/123 个温度传感器 ===
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.316389 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 207291
# [LightGBM] [Info] Number of data points in the train set: 51852, number of used features: 1066
# [LightGBM] [Info] Start training from score 50.844268
# MAE: 1.65, RMSE: 2.31, R²: 0.9891
#
# === 所有传感器平均表现 ===
# 平均 MAE: 1.09
# 平均 RMSE: 1.59
# 平均 R²: 0.9941
# 结果已保存到 sensor_performance_summary.csv
